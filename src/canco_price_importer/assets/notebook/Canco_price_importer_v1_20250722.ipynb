# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime
# pd.options.display.float_format = '{:.2f}'.format
# pd.set_option('display.float_format', '{:.6f}'.format)

import warnings
import os
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Mapping

# %%
supplier_code_map = {
    'Toronto': 'CAN-TOR-ON',
    'Hamilton': 'CAN-HAM-ON',
    'Sarnia': 'CAN-SAR-ON',
    'London': 'CAN-LON-ON',
    # 'Calgary': '', # Code?
    # 'Edmonton': '', # Code?
    'Kamloops': 'CAN-KAM-BC',
    'Vancouver': 'CAN-BUR-BC', # Code?
    'Winnipeg': 'CAN-WIN-MB',
    'Thunder Bay': 'CAN-TBY-ON',
}

inventory_item_map = {
    'Regular': 'RUL87',
    'Premium': 'PUL91',
    'Diesel': 'ULSD',
    'Dyd Diesel': 'ULSDD',
    'Winter Diesel': 'WULSD'
}

supplier_item_map = {
    'RUL87': 'GAS',
    'PUL91': 'GAS',
    'ULSD': 'DIESEL',
    'WULSD': 'DIESEL',
    'ULSDD': 'DYED',
}

# %% [markdown]
# ## Load csv

# %%
df_csv = pd.read_csv('Supplier Cost Import 01.26.25.csv')

# %% [markdown]
# ## East

# %%
df_east = pd.read_excel("East.xlsx", engine = 'openpyxl')
df_east = df_east.dropna(how='all').dropna(how='all', axis = 1)

# %%
import pandas as pd
from datetime import timedelta

def get_effective_date(data):
    original_datetime = pd.to_datetime(
        data['Unnamed: 1'][data['Unnamed: 1'].str.contains('Effective') == True]
        .str.split('Effective date: ')
        .str[-1]
    ).values[0]
    
    # Add 1 minute
    adjusted_datetime = pd.Timestamp(original_datetime) + timedelta(minutes=1)
    
    # Manually format date to '1/25/25 0:01'
    formatted_datetime = f"{adjusted_datetime.month}/{adjusted_datetime.day}/{adjusted_datetime.strftime('%y')} {adjusted_datetime.hour}:{adjusted_datetime.strftime('%M')}"
    
    return formatted_datetime

# %%
formatted_datetime = get_effective_date(df_east)

# %%
def parse_east(data, update_datetime):
    df = data.iloc[5:]

    results = []
    i = 0
    while i < len(df):
        row = df.iloc[i]
    
        # Detect city names (non-NaN in column 0, NaNs elsewhere)
        if pd.notna(row[0]) and row[1:].isna().all():
            city = row[0]
            # Look ahead to find 'Base Price' row
            for j in range(i + 1, min(i + 10, len(df))):
                if str(df.iloc[j, 0]).strip() == "Base Price":
                    grades = df.iloc[j - 1]  # One row above 'Base Price' has fuel grade headers
                    prices = df.iloc[j]
    
                    price_dict = {"grades": {}}
                    for k in range(1, len(grades)):
                        if pd.notna(grades[k]):
                            price_dict['grades'][grades[k]]=prices[k]
                            if grades[k] == 'Diesel':
                                price_dict['grades']['Winter Diesel']=prices[k]
                    result = {"city": city}
                    result.update(price_dict)
                    results.append(result)
                    i = j  # skip to after 'Base Price'
                    break
        i += 1
    return results

# %%
results = parse_east(df_east, formatted_datetime)

# %%
def get_dataframe(results, columns):
    num = 0
    df = pd.DataFrame(columns =columns)
    for result in results:
        if result['city'] in supplier_code_map:
            for grade, price in result['grades'].items():
                df.loc[num] = [
                    supplier_code_map[result['city']], 
                     supplier_item_map[inventory_item_map[grade]],
                     inventory_item_map[grade],
                     formatted_datetime,
                     price]
                num += 1
    return df

# %%
df_east_cleaned = get_dataframe(results, df_csv.columns)

# %% [markdown]
# # Rest

# %%
df_rest = pd.read_excel("Rest.xlsx", engine = 'openpyxl')
df_rest = df_rest.dropna(how='all').dropna(how='all', axis = 1)

# %%
formatted_datetime = get_effective_date(df_rest)

# %%
def parse_rest(data, update_datetime):
    df = data.iloc[5:-6]

    results =[]

    for row_num in range(len(df)):
        row = df.iloc[row_num]
    
        result = {}
        result['grades'] = {}
    
        if pd.notna(row[0]) and pd.isna(row[1]):
            # print(row[0])
            city = row[0].split(',')[0]
            result['city'] = city
    
            for j in range(row_num+2, min(row_num+5, len(df_rest))):
                # print(df_rest.iloc[j])
                grade = df.iloc[j][0]
                price = df.iloc[j][1]
                result['grades'][grade]=price
                if grade == 'Diesel':
                    result['grades']['Dyd Diesel']=price
                    result['grades']['Winter Diesel']=price
            results.append(result)
    return results

# %%
results = parse_rest(df_rest, formatted_datetime)

# %%
df_rest_cleaned = get_dataframe(results, df_csv.columns)

# %% [markdown]
# ## Merge

# %%
df_concat =pd.concat([df_east_cleaned, df_rest_cleaned]).sort_values(by = ['Supplier Code', 'Inventory Item', 'Cost'], ascending = True)

# %%
df_concat =df_concat.drop_duplicates(subset = ['Supplier Code', 'Inventory Item'], keep = 'last')

# %%
df_merge = pd.merge(left = df_csv, right = df_concat[['Supplier Code', 'Inventory Item', 'Cost', 'Effective DateTime']], how = 'left', on = ['Supplier Code', 'Inventory Item'], 
        suffixes = ('', '_new'))

# %%
df_update = df_csv.copy()

# %%
df_update['Cost'] = df_merge['Cost_new'].combine_first(df_update['Cost'])

# %%
df_update['Effective DateTime'] = df_merge['Effective DateTime_new'].combine_first(df_update['Effective DateTime'])

# %%
df_update
# Out:
#      Supplier Code  Supplier Item Inventory Item Effective DateTime    Cost
# 0       CAN-BUR-BC            GAS          PUL91       7/19/25 0:01  1.3030
# 1       CAN-BUR-BC            GAS          RUL87       7/19/25 0:01  1.1280
# 2       CAN-BUR-BC           DYED          ULSDD       7/19/25 0:01  1.3520
# 3       CAN-BUR-BC         DIESEL           ULSD       7/19/25 0:01  1.3520
# 4       CAN-BUR-BC         DIESEL          WULSD       7/19/25 0:01  1.3520
# 5       CAN-KAM-BC            GAS          PUL91       7/19/25 0:01  1.2430
# 6       CAN-KAM-BC            GAS          RUL87       7/19/25 0:01  1.0530
# 7       CAN-KAM-BC           DYED          ULSDD       7/19/25 0:01  1.2350
# 8       CAN-KAM-BC         DIESEL           ULSD       7/19/25 0:01  1.2350
# 9       CAN-KAM-BC         DIESEL          WULSD       7/19/25 0:01  1.2350
# 10      CAN-TOR-ON            GAS          PUL91       7/19/25 0:01  1.0700
# 11      CAN-TOR-ON            GAS          RUL87       7/19/25 0:01  0.8950
# 12      CAN-TOR-ON           DYED          ULSDD       7/19/25 0:01  1.0520
# 13      CAN-TOR-ON         DIESEL           ULSD       7/19/25 0:01  1.0520
# 14      CAN-TOR-ON         DIESEL          WULSD       7/19/25 0:01  1.0520
# 15  CAN-SHE-TOR-ON            GAS          PUL91       1/27/25 0:01  0.9835
# 16  CAN-SHE-TOR-ON            GAS          RUL87       1/27/25 0:01  0.8085
# 17  CAN-SHE-TOR-ON           DYED          ULSDD       1/27/25 0:01  1.0015
# 18  CAN-SHE-TOR-ON         DIESEL           ULSD       1/27/25 0:01  1.0015
# 19  CAN-SHE-TOR-ON         DIESEL          WULSD       1/27/25 0:01  1.0015
# 20      CAN-TBY-ON            GAS          PUL91       7/19/25 0:01  1.1450
# 21      CAN-TBY-ON            GAS          RUL87       7/19/25 0:01  0.9550
# 22      CAN-TBY-ON           DYED          ULSDD       7/19/25 0:01  1.0820
# 23      CAN-TBY-ON         DIESEL           ULSD       7/19/25 0:01  1.0820
# 24      CAN-TBY-ON         DIESEL          WULSD       7/19/25 0:01  1.0820
# 25      CAN-SAR-ON            GAS          PUL91       7/19/25 0:01  1.0700
# 26      CAN-SAR-ON            GAS          RUL87       7/19/25 0:01  0.8950
# 27      CAN-SAR-ON           DYED          ULSDD       7/19/25 0:01  1.0520
# 28      CAN-SAR-ON         DIESEL           ULSD       7/19/25 0:01  1.0520
# 29      CAN-SAR-ON         DIESEL          WULSD       7/19/25 0:01  1.0520
# 30  CAN-SHE-SAR-ON            GAS          PUL91       1/27/25 0:01  0.9735
# 31  CAN-SHE-SAR-ON            GAS          RUL87       1/27/25 0:01  0.7985
# 32  CAN-SHE-SAR-ON           DYED          ULSDD       1/27/25 0:01  0.9815
# 33  CAN-SHE-SAR-ON         DIESEL           ULSD       1/27/25 0:01  0.9815
# 34  CAN-SHE-SAR-ON         DIESEL          WULSD       1/27/25 0:01  0.9815
# 35      CAN-HAM-ON            GAS          PUL91       7/19/25 0:01  1.0700
# 36      CAN-HAM-ON            GAS          RUL87       7/19/25 0:01  0.8950
# 37      CAN-HAM-ON           DYED          ULSDD       7/19/25 0:01  1.0520
# 38      CAN-HAM-ON         DIESEL           ULSD       7/19/25 0:01  1.0520
# 39      CAN-HAM-ON         DIESEL          WULSD       7/19/25 0:01  1.0520
# 40      CAN-LON-ON            GAS          PUL91       7/19/25 0:01  1.0600
# 41      CAN-LON-ON            GAS          RUL87       7/19/25 0:01  0.8850
# 42      CAN-LON-ON           DYED          ULSDD       7/19/25 0:01  1.0320
# 43      CAN-LON-ON         DIESEL           ULSD       7/19/25 0:01  1.0320
# 44      CAN-LON-ON         DIESEL          WULSD       7/19/25 0:01  1.0320
# 45      CAN-WIN-MB            GAS          PUL91       7/19/25 0:01  1.1050
# 46      CAN-WIN-MB            GAS          RUL87       7/19/25 0:01  0.9150
# 47      CAN-WIN-MB           DYED          ULSDD       7/19/25 0:01  1.0890
# 48      CAN-WIN-MB         DIESEL           ULSD       7/19/25 0:01  1.0890
# 49      CAN-WIN-MB         DIESEL          WULSD       7/19/25 0:01  1.0890
# 50      ECO-LON-ON            GAS          PUL91       1/17/25 0:01  1.1910
# 51      ECO-LON-ON            GAS          RUL87       1/17/25 0:01  1.0010
# 52      ECO-LON-ON           DYED          ULSDD       1/17/25 0:01  1.1300
# 53      ECO-LON-ON         DIESEL           ULSD       1/17/25 0:01  1.1300
# 54      ECO-LON-ON         DIESEL          WULSD       1/17/25 0:01  1.1820
# 55      ECO-NAN-ON            GAS          PUL91       1/17/25 0:01  1.1910
# 56      ECO-NAN-ON            GAS          RUL87       1/17/25 0:01  1.0010
# 57      ECO-NAN-ON           DYED          ULSDD       1/17/25 0:01  1.1300
# 58      ECO-NAN-ON         DIESEL           ULSD       1/17/25 0:01  1.1300
# 59      ECO-NAN-ON         DIESEL          WULSD       1/17/25 0:01  1.1820
# 60      ECO-SAR-ON            GAS          PUL91       1/17/25 0:01  1.1910
# 61      ECO-SAR-ON            GAS          RUL87       1/17/25 0:01  1.0010
# 62      ECO-SAR-ON           DYED          ULSDD       1/17/25 0:01  1.1300
# 63      ECO-SAR-ON         DIESEL           ULSD       1/17/25 0:01  1.1300
# 64      ECO-SAR-ON         DIESEL          WULSD       1/17/25 0:01  1.1820
# 65      ECO-TBY-ON            GAS          PUL91       1/17/25 0:01  1.1910
# 66      ECO-TBY-ON            GAS          RUL87       1/17/25 0:01  1.0010
# 67      ECO-TBY-ON           DYED          ULSDD       1/17/25 0:01  1.1300
# 68      ECO-TBY-ON         DIESEL           ULSD       1/17/25 0:01  1.1300
# 69      ECO-TBY-ON         DIESEL          WULSD       1/17/25 0:01  1.1820
# 70      ECO-TOR-ON            GAS          PUL91       1/17/25 0:01  1.1910
# 71      ECO-TOR-ON            GAS          RUL87       1/17/25 0:01  1.0010
# 72      ECO-TOR-ON           DYED          ULSDD       1/17/25 0:01  1.1300
# 73      ECO-TOR-ON         DIESEL           ULSD       1/17/25 0:01  1.1300
# 74      ECO-TOR-ON         DIESEL          WULSD       1/17/25 0:01  1.1820
# 75      NLP-WIN-MB            GAS          PUL91       1/17/25 0:01  1.1910
# 76      NLP-WIN-MB            GAS          RUL87       1/17/25 0:01  1.0010
# 77      NLP-WIN-MB           DYED          ULSDD       1/17/25 0:01  1.1300
# 78      NLP-WIN-MB         DIESEL           ULSD       1/17/25 0:01  1.1300
# 79      NLP-WIN-MB         DIESEL          WULSD       1/17/25 0:01  1.1820

# %% [markdown]
# # End
